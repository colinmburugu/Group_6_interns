# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_stata("data/5pct_sample_2019_10.dta")

# %%
df.head()
# Out:
#    date  shop_code                 region      price  item
# 0   323        188  Catalogue collections  52.000000   349
# 1   326        188  Catalogue collections  77.000000   349
# 2   332        188  Catalogue collections  49.000000   349
# 3   328        203  Catalogue collections  37.000000   349
# 4   337        203  Catalogue collections  39.990002   349

# %%
selecteditems= pd.read_csv("data/selecteditems.csv")

# %%
selecteditems.head(5)
# Out:
#    quote_date   item_id        name  date    median   price         p  keep  \
# 0      198802  212511.0  C. Lettuce   1.0  0.776667    10.0  0.677500   1.0
# 1      198802  212511.0  C. Lettuce   1.0  0.776667  1020.0  0.012917   1.0
# 2      198802  212511.0  C. Lettuce   1.0  0.776667  2030.0  0.030000   1.0
# 3      198802  212511.0  C. Lettuce   1.0  0.776667  3040.0  0.023333   1.0
# 4      198802  212511.0  C. Lettuce   1.0  0.776667  4050.0  0.032917   1.0
#
#         date2       date3     newDate       _merge
# 0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 1  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 2  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 3  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 4  01-02-1988  01-02-1988  1988-02-01  matched (3)

# %%
selecteditems.isnull().sum()
# Out:
# quote_date    0
# item_id       2
# name          2
# date          2
# median        2
# price         2
# p             2
# keep          2
# date2         0
# date3         0
# newDate       0
# _merge        0
# dtype: int64

# %%
selecteditems.count()
# Out:
# quote_date    13898
# item_id       13896
# name          13896
# date          13896
# median        13896
# price         13896
# p             13896
# keep          13896
# date2         13898
# date3         13898
# newDate       13898
# _merge        13898
# dtype: int64

# %%
selecteditems[selecteditems["date"].isna()]
# Out:
#        quote_date  item_id name  date  median  price   p  keep       date2  \
# 13896      198808      NaN  NaN   NaN     NaN    NaN NaN   NaN  01-08-1988
# 13897      198902      NaN  NaN   NaN     NaN    NaN NaN   NaN  01-02-1989
#
#             date3     newDate          _merge
# 13896  01-08-1988  1988-08-01  using only (2)
# 13897  01-02-1989  1989-02-01  using only (2)

# %% [markdown]
# We have to delete these rows because they don't have any value

# %%
selecteditems = selecteditems.dropna()

# %%
selecteditems.isnull().sum()
# Out:
# quote_date    0
# item_id       0
# name          0
# date          0
# median        0
# price         0
# p             0
# keep          0
# date2         0
# date3         0
# newDate       0
# _merge        0
# dtype: int64

# %%
selecteditems.count()
# Out:
# quote_date    13896
# item_id       13896
# name          13896
# date          13896
# median        13896
# price         13896
# p             13896
# keep          13896
# date2         13896
# date3         13896
# newDate       13896
# _merge        13896
# dtype: int64

# %%
selecteditems["date"] = selecteditems["date"].astype(int)

# %%
selecteditems["item_id"] = selecteditems["item_id"].astype(int)

# %%
selecteditems.head()
# Out:
#    quote_date  item_id        name  date    median   price         p  keep  \
# 0      198802   212511  C. Lettuce     1  0.776667    10.0  0.677500   1.0
# 1      198802   212511  C. Lettuce     1  0.776667  1020.0  0.012917   1.0
# 2      198802   212511  C. Lettuce     1  0.776667  2030.0  0.030000   1.0
# 3      198802   212511  C. Lettuce     1  0.776667  3040.0  0.023333   1.0
# 4      198802   212511  C. Lettuce     1  0.776667  4050.0  0.032917   1.0
#
#         date2       date3     newDate       _merge
# 0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 1  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 2  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 3  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 4  01-02-1988  01-02-1988  1988-02-01  matched (3)

# %%
selecteditems["name"].value_counts()
# Out:
# C. Lettuce        3537
# D. Cigarettes     3528
# B. Men's socks    3528
# A. Pub Meal       3303
# Name: name, dtype: int64

# %%
items = pd.read_csv("items_2019_10.csv")

# %%
items.head()
# Out:
#    item  item_id                     description
# 0     1   210101    LARGE LOAF-WHITE-SLICED-800G
# 1     2   210102  LARGE LOAF-WHITE-UNSLICED-800G
# 2     3   210105   LARGE WHOLEMEAL LOAF-UNSLICED
# 3     4   210106  SIX BREAD ROLLS-WHITE/BROWN
# 4     5   210107     BROWN LOAF,400G,SLICED-GRAN

# %%
items[items["item_id"]== 212511]
# Out:
#      item  item_id                     description
# 249   250   212511  FRESH VEG-LETTUCE-ICEBERG-EACH

# %%
lettuce_data = df[df["item"] == 250]

# %%
lettuce_data = lettuce_data.merge(items, on="item")

# %%
lettuce_data.head(25)
# Out:
#     date  shop_code  region  price  item  item_id  \
# 0     23          1  London   0.99   250   212511
# 1    119          1  London   0.80   250   212511
# 2    194          1  London   0.59   250   212511
# 3    263          2  London   0.79   250   212511
# 4    102          4  London   0.42   250   212511
# 5    136          4  London   0.99   250   212511
# 6    139          4  London   0.89   250   212511
# 7    149          4  London   0.89   250   212511
# 8    320          4  London   0.60   250   212511
# 9    330          4  London   0.60   250   212511
# 10   331          4  London   0.60   250   212511
# 11   360          4  London   0.45   250   212511
# 12    40          6  London   0.59   250   212511
# 13    42          6  London   0.58   250   212511
# 14   375          6  London   1.20   250   212511
# 15    50          7  London   1.19   250   212511
# 16   133          7  London   0.39   250   212511
# 17   363          7  London   0.65   250   212511
# 18    53          8  London   0.35   250   212511
# 19    64          8  London   0.60   250   212511
# 20    69          8  London   0.50   250   212511
# 21    24          9  London   0.50   250   212511
# 22   100         10  London   0.30   250   212511
# 23   117         10  London   0.60   250   212511
# 24   172         11  London   0.55   250   212511
#
#                        description
# 0   FRESH VEG-LETTUCE-ICEBERG-EACH
# 1   FRESH VEG-LETTUCE-ICEBERG-EACH
# 2   FRESH VEG-LETTUCE-ICEBERG-EACH
# 3   FRESH VEG-LETTUCE-ICEBERG-EACH
# 4   FRESH VEG-LETTUCE-ICEBERG-EACH
# 5   FRESH VEG-LETTUCE-ICEBERG-EACH
# 6   FRESH VEG-LETTUCE-ICEBERG-EACH
# 7   FRESH VEG-LETTUCE-ICEBERG-EACH
# 8   FRESH VEG-LETTUCE-ICEBERG-EACH
# 9   FRESH VEG-LETTUCE-ICEBERG-EACH
# 10  FRESH VEG-LETTUCE-ICEBERG-EACH
# 11  FRESH VEG-LETTUCE-ICEBERG-EACH
# 12  FRESH VEG-LETTUCE-ICEBERG-EACH
# 13  FRESH VEG-LETTUCE-ICEBERG-EACH
# 14  FRESH VEG-LETTUCE-ICEBERG-EACH
# 15  FRESH VEG-LETTUCE-ICEBERG-EACH
# 16  FRESH VEG-LETTUCE-ICEBERG-EACH
# 17  FRESH VEG-LETTUCE-ICEBERG-EACH
# 18  FRESH VEG-LETTUCE-ICEBERG-EACH
# 19  FRESH VEG-LETTUCE-ICEBERG-EACH
# 20  FRESH VEG-LETTUCE-ICEBERG-EACH
# 21  FRESH VEG-LETTUCE-ICEBERG-EACH
# 22  FRESH VEG-LETTUCE-ICEBERG-EACH
# 23  FRESH VEG-LETTUCE-ICEBERG-EACH
# 24  FRESH VEG-LETTUCE-ICEBERG-EACH

# %%
lettuce_data = lettuce_data.sort_values(by=["date"] )

# %%
lettuce_data.head(25)
# Out:
#       date  shop_code              region  price  item  item_id  \
# 2499     1          1  Yorkshire & Humber   0.69   250   212511
# 1490     1          7         East Anglia   0.69   250   212511
# 1492     1         10         East Anglia   0.70   250   212511
# 2503     1          2  Yorkshire & Humber   0.85   250   212511
# 2618     1         45  Yorkshire & Humber   0.79   250   212511
# 3876     1         15            Scotland   0.95   250   212511
# 577      1         29          South East   0.69   250   212511
# 1457     1          3         East Anglia   0.69   250   212511
# 2944     1         18          North West   1.20   250   212511
# 3586     2          4               Wales   0.80   250   212511
# 2689     2         97  Yorkshire & Humber   0.90   250   212511
# 4387     2         10                  99   0.64   250   212511
# 3845     2          6            Scotland   0.85   250   212511
# 528      2         13          South East   0.60   250   212511
# 3865     2         11            Scotland   0.60   250   212511
# 2721     2        130  Yorkshire & Humber   0.79   250   212511
# 557      3         22          South East   0.99   250   212511
# 2971     3         28          North West   0.55   250   212511
# 1822     3          9       East Midlands   0.55   250   212511
# 4406     3         39                  99   0.65   250   212511
# 2279     3         82       West Midlands   0.54   250   212511
# 2899     3          3          North West   0.65   250   212511
# 1513     4         27         East Anglia   0.75   250   212511
# 2145     4          9       West Midlands   0.79   250   212511
# 1809     4          5       East Midlands   0.80   250   212511
#
#                          description
# 2499  FRESH VEG-LETTUCE-ICEBERG-EACH
# 1490  FRESH VEG-LETTUCE-ICEBERG-EACH
# 1492  FRESH VEG-LETTUCE-ICEBERG-EACH
# 2503  FRESH VEG-LETTUCE-ICEBERG-EACH
# 2618  FRESH VEG-LETTUCE-ICEBERG-EACH
# 3876  FRESH VEG-LETTUCE-ICEBERG-EACH
# 577   FRESH VEG-LETTUCE-ICEBERG-EACH
# 1457  FRESH VEG-LETTUCE-ICEBERG-EACH
# 2944  FRESH VEG-LETTUCE-ICEBERG-EACH
# 3586  FRESH VEG-LETTUCE-ICEBERG-EACH
# 2689  FRESH VEG-LETTUCE-ICEBERG-EACH
# 4387  FRESH VEG-LETTUCE-ICEBERG-EACH
# 3845  FRESH VEG-LETTUCE-ICEBERG-EACH
# 528   FRESH VEG-LETTUCE-ICEBERG-EACH
# 3865  FRESH VEG-LETTUCE-ICEBERG-EACH
# 2721  FRESH VEG-LETTUCE-ICEBERG-EACH
# 557   FRESH VEG-LETTUCE-ICEBERG-EACH
# 2971  FRESH VEG-LETTUCE-ICEBERG-EACH
# 1822  FRESH VEG-LETTUCE-ICEBERG-EACH
# 4406  FRESH VEG-LETTUCE-ICEBERG-EACH
# 2279  FRESH VEG-LETTUCE-ICEBERG-EACH
# 2899  FRESH VEG-LETTUCE-ICEBERG-EACH
# 1513  FRESH VEG-LETTUCE-ICEBERG-EACH
# 2145  FRESH VEG-LETTUCE-ICEBERG-EACH
# 1809  FRESH VEG-LETTUCE-ICEBERG-EACH

# %%
lettuce_data = lettuce_data.merge(selecteditems, on=["date", "item_id"])

# %%
lettuce_data.head(25)
# Out:
#     date  shop_code              region  price_x  item  item_id  \
# 0      1          1  Yorkshire & Humber     0.69   250   212511
# 1      1          1  Yorkshire & Humber     0.69   250   212511
# 2      1          1  Yorkshire & Humber     0.69   250   212511
# 3      1          1  Yorkshire & Humber     0.69   250   212511
# 4      1          1  Yorkshire & Humber     0.69   250   212511
# 5      1          1  Yorkshire & Humber     0.69   250   212511
# 6      1          1  Yorkshire & Humber     0.69   250   212511
# 7      1          1  Yorkshire & Humber     0.69   250   212511
# 8      1          1  Yorkshire & Humber     0.69   250   212511
# 9      1          7         East Anglia     0.69   250   212511
# 10     1          7         East Anglia     0.69   250   212511
# 11     1          7         East Anglia     0.69   250   212511
# 12     1          7         East Anglia     0.69   250   212511
# 13     1          7         East Anglia     0.69   250   212511
# 14     1          7         East Anglia     0.69   250   212511
# 15     1          7         East Anglia     0.69   250   212511
# 16     1          7         East Anglia     0.69   250   212511
# 17     1          7         East Anglia     0.69   250   212511
# 18     1         10         East Anglia     0.70   250   212511
# 19     1         10         East Anglia     0.70   250   212511
# 20     1         10         East Anglia     0.70   250   212511
# 21     1         10         East Anglia     0.70   250   212511
# 22     1         10         East Anglia     0.70   250   212511
# 23     1         10         East Anglia     0.70   250   212511
# 24     1         10         East Anglia     0.70   250   212511
#
#                        description  quote_date        name    median  price_y  \
# 0   FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667     10.0
# 1   FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   1020.0
# 2   FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   2030.0
# 3   FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   3040.0
# 4   FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   4050.0
# 5   FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   5060.0
# 6   FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   6070.0
# 7   FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   7080.0
# 8   FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   8090.0
# 9   FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667     10.0
# 10  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   1020.0
# 11  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   2030.0
# 12  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   3040.0
# 13  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   4050.0
# 14  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   5060.0
# 15  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   6070.0
# 16  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   7080.0
# 17  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   8090.0
# 18  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667     10.0
# 19  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   1020.0
# 20  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   2030.0
# 21  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   3040.0
# 22  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   4050.0
# 23  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   5060.0
# 24  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   6070.0
#
#            p  keep       date2       date3     newDate       _merge
# 0   0.677500   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 1   0.012917   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 2   0.030000   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 3   0.023333   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 4   0.032917   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 5   0.034583   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 6   0.050417   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 7   0.072500   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 8   0.042917   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 9   0.677500   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 10  0.012917   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 11  0.030000   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 12  0.023333   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 13  0.032917   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 14  0.034583   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 15  0.050417   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 16  0.072500   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 17  0.042917   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 18  0.677500   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 19  0.012917   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 20  0.030000   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 21  0.023333   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 22  0.032917   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 23  0.034583   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)
# 24  0.050417   1.0  01-02-1988  01-02-1988  1988-02-01  matched (3)

# %%
lettuce_data.shape
# Out:
# (39726, 17)

# %%
lettuce_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39726 entries, 0 to 39725
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         39726 non-null  int16
#  1   shop_code    39726 non-null  int16
#  2   region       39726 non-null  category
#  3   price_x      39726 non-null  float32
#  4   item         39726 non-null  int16
#  5   item_id      39726 non-null  int64
#  6   description  39726 non-null  object
#  7   quote_date   39726 non-null  int64
#  8   name         39726 non-null  object
#  9   median       39726 non-null  float64
#  10  price_y      39726 non-null  float64
#  11  p            39726 non-null  float64
#  12  keep         39726 non-null  float64
#  13  date2        39726 non-null  object
#  14  date3        39726 non-null  object
#  15  newDate      39726 non-null  object
#  16  _merge       39726 non-null  object
# dtypes: category(1), float32(1), float64(4), int16(3), int64(2), object(6)
# memory usage: 4.4+ MB

# %%
lettuce_data['newDate'] = lettuce_data['newDate'].apply(lambda x : datetime.strptime(x, '%Y-%m-%d'))
lettuce_data['Year'] = lettuce_data['newDate'].dt.year
lettuce_data['Month'] = lettuce_data['newDate'].dt.month

# %%
lettuce_data.head()
# Out:
#    date  shop_code              region  price_x  item  item_id  \
# 0     1          1  Yorkshire & Humber     0.69   250   212511
# 1     1          1  Yorkshire & Humber     0.69   250   212511
# 2     1          1  Yorkshire & Humber     0.69   250   212511
# 3     1          1  Yorkshire & Humber     0.69   250   212511
# 4     1          1  Yorkshire & Humber     0.69   250   212511
#
#                       description  quote_date        name    median  price_y  \
# 0  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667     10.0
# 1  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   1020.0
# 2  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   2030.0
# 3  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   3040.0
# 4  FRESH VEG-LETTUCE-ICEBERG-EACH      198802  C. Lettuce  0.776667   4050.0
#
#           p  keep       date2       date3    newDate       _merge  Year  Month
# 0  0.677500   1.0  01-02-1988  01-02-1988 1988-02-01  matched (3)  1988      2
# 1  0.012917   1.0  01-02-1988  01-02-1988 1988-02-01  matched (3)  1988      2
# 2  0.030000   1.0  01-02-1988  01-02-1988 1988-02-01  matched (3)  1988      2
# 3  0.023333   1.0  01-02-1988  01-02-1988 1988-02-01  matched (3)  1988      2
# 4  0.032917   1.0  01-02-1988  01-02-1988 1988-02-01  matched (3)  1988      2

# %%
lettuce_data.drop(columns = 'quote_date', axis = 1, inplace = True)
lettuce_data.drop(columns = 'date2', axis = 1, inplace = True)
lettuce_data.drop(columns = 'date3', axis = 1, inplace = True)

# %%
lettuce_data.head()
# Out:
#    date  shop_code              region  price_x  item  item_id  \
# 0     1          1  Yorkshire & Humber     0.69   250   212511
# 1     1          1  Yorkshire & Humber     0.69   250   212511
# 2     1          1  Yorkshire & Humber     0.69   250   212511
# 3     1          1  Yorkshire & Humber     0.69   250   212511
# 4     1          1  Yorkshire & Humber     0.69   250   212511
#
#                       description        name    median  price_y         p  \
# 0  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.776667     10.0  0.677500
# 1  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.776667   1020.0  0.012917
# 2  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.776667   2030.0  0.030000
# 3  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.776667   3040.0  0.023333
# 4  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.776667   4050.0  0.032917
#
#    keep    newDate       _merge  Year  Month
# 0   1.0 1988-02-01  matched (3)  1988      2
# 1   1.0 1988-02-01  matched (3)  1988      2
# 2   1.0 1988-02-01  matched (3)  1988      2
# 3   1.0 1988-02-01  matched (3)  1988      2
# 4   1.0 1988-02-01  matched (3)  1988      2

# %% [markdown]
# ## Explatory Data Analysis

# %% [markdown]
# Number of regions

# %%
print('Number of regions:', lettuce_data['region'].nunique())
# Out:
# Number of regions: 13

# %%
lettuce_data['region'].value_counts()
# Out:
# South East               5436
# London                   4302
# North West               3915
# Yorkshire & Humber       3591
# Scotland                 3501
# West Midlands            3330
# South West               3303
# East Midlands            3060
# East Anglia              2997
# North                    2232
# Wales                    2205
# Northern Ireland         1395
# 99                        459
# Catalogue collections       0
# Name: region, dtype: int64

# %% [markdown]
# Average lettuce price per year

# %%
lettuce_data.groupby('Year')['price_x'].median()
# Out:
# Year
# 1988    0.700
# 1989    0.785
# 1990    0.835
# 1991    0.695
# 1992    0.690
# 1993    0.645
# 1994    0.650
# 1995    0.690
# 1996    0.580
# 1997    0.600
# 1998    0.590
# 1999    0.590
# 2000    0.500
# 2001    0.650
# 2002    0.650
# 2003    0.750
# 2004    0.650
# 2005    0.690
# 2006    0.750
# 2007    0.790
# 2008    0.850
# 2009    0.870
# 2010    0.950
# 2011    0.890
# 2012    1.000
# 2013    1.000
# 2014    0.750
# 2015    0.550
# 2016    0.500
# 2017    0.500
# 2018    0.600
# 2019    0.620
# Name: price_x, dtype: float32

# %% [markdown]
# Minimum price per year

# %%
lettuce_data.groupby('Year')['price_x'].min()
# Out:
# Year
# 1988    0.45
# 1989    0.45
# 1990    0.30
# 1991    0.30
# 1992    0.35
# 1993    0.22
# 1994    0.29
# 1995    0.35
# 1996    0.25
# 1997    0.25
# 1998    0.29
# 1999    0.35
# 2000    0.25
# 2001    0.25
# 2002    0.38
# 2003    0.39
# 2004    0.25
# 2005    0.39
# 2006    0.39
# 2007    0.40
# 2008    0.37
# 2009    0.39
# 2010    0.40
# 2011    0.39
# 2012    0.50
# 2013    0.39
# 2014    0.39
# 2015    0.34
# 2016    0.39
# 2017    0.39
# 2018    0.42
# 2019    0.25
# Name: price_x, dtype: float32

# %% [markdown]
# Maximum price per year

# %%
lettuce_data.groupby('Year')['price_x'].max()
# Out:
# Year
# 1988    1.20
# 1989    1.09
# 1990    1.19
# 1991    1.25
# 1992    1.20
# 1993    1.29
# 1994    0.95
# 1995    1.04
# 1996    1.59
# 1997    1.25
# 1998    0.99
# 1999    1.35
# 2000    0.99
# 2001    1.49
# 2002    1.20
# 2003    1.79
# 2004    1.40
# 2005    1.80
# 2006    1.20
# 2007    1.49
# 2008    1.50
# 2009    1.50
# 2010    1.95
# 2011    1.32
# 2012    1.99
# 2013    1.50
# 2014    1.29
# 2015    1.29
# 2016    1.50
# 2017    1.20
# 2018    1.50
# 2019    1.29
# Name: price_x, dtype: float32

# %%
average_price = lettuce_data.groupby(['price_x', 'Year'], as_index = False)['price_x'].median()

# %% [markdown]
# Median price distribution per year of lettuce

# %%
sns.relplot(kind = 'line', data = average_price, 
            x = 'Year', y = 'price_x', aspect=3);

# %% [markdown]
# Median price across all regions

# %%
lettuce_data.groupby(lettuce_data['region'])['price_x'].median().sort_values(ascending = False).plot(
    kind = "bar",grid = True, figsize = (16,6))
# Out:
# <AxesSubplot:xlabel='region'>

# %% [markdown]
# - 2008 Financial crush
# - 2016 EU referendum
# - 2019 Covid

# %%
lettuce_data_2008 = lettuce_data[lettuce_data['Year'] == 2008].copy()


lettuce_data_2008_price_per_month = lettuce_data_2008.groupby(['region','Month'], as_index=False)['price_x'].median()

# %%
sns.relplot(kind='line', data = lettuce_data_2008_price_per_month, x = 'Month', y = 'price_x', hue = 'region', aspect = 2);

# %%
print('Number of shops:', lettuce_data['shop_code'].nunique())
# Out:
# Number of shops: 247

# %%
lettuce_data.head()
# Out:
#    date  shop_code              region  price_x  item  item_id  \
# 0     1          1  Yorkshire & Humber     0.69   250   212511
# 1     1          1  Yorkshire & Humber     0.69   250   212511
# 2     1          1  Yorkshire & Humber     0.69   250   212511
# 3     1          1  Yorkshire & Humber     0.69   250   212511
# 4     1          1  Yorkshire & Humber     0.69   250   212511
#
#                       description        name    median  price_y         p  \
# 0  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.776667     10.0  0.677500
# 1  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.776667   1020.0  0.012917
# 2  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.776667   2030.0  0.030000
# 3  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.776667   3040.0  0.023333
# 4  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.776667   4050.0  0.032917
#
#    keep    newDate       _merge  Year  Month
# 0   1.0 1988-02-01  matched (3)  1988      2
# 1   1.0 1988-02-01  matched (3)  1988      2
# 2   1.0 1988-02-01  matched (3)  1988      2
# 3   1.0 1988-02-01  matched (3)  1988      2
# 4   1.0 1988-02-01  matched (3)  1988      2

# %%
lettuce_data_2008_price_per_month = lettuce_data_2008.groupby(['Month'], as_index=False)['price_x'].median()

# %%
sns.relplot(kind='line', data = lettuce_data_2008_price_per_month, x = 'Month', y = 'price_x',  aspect = 3);

# %%
lettuce_data_2016 = lettuce_data[lettuce_data['Year'] == 2016].copy()

lettuce_data_2016_price_per_month = lettuce_data_2016.groupby(['Month'], as_index=False)['price_x'].median()

# %%
sns.relplot(kind='line', data = lettuce_data_2016_price_per_month, x = 'Month', y = 'price_x',  aspect = 3);

# %%
lettuce_data_2019 = lettuce_data[lettuce_data['Year'] == 2019].copy()

lettuce_data_2019_price_per_month = lettuce_data_2019.groupby(['Month'], as_index=False)['price_x'].median()

# %%
sns.relplot(kind='line', data = lettuce_data_2019_price_per_month, x = 'Month', y = 'price_x',  aspect = 3);

# %%
lettuce_data[lettuce_data["region"]==99]
# Out:
#       date  shop_code region  price_x  item  item_id  \
# 99       2         10     99     0.64   250   212511
# 100      2         10     99     0.64   250   212511
# 101      2         10     99     0.64   250   212511
# 102      2         10     99     0.64   250   212511
# 103      2         10     99     0.64   250   212511
# ...    ...        ...    ...      ...   ...      ...
# 5251    67          7     99     0.39   250   212511
# 5252    67          7     99     0.39   250   212511
# 5253    67          7     99     0.39   250   212511
# 5254    67          7     99     0.39   250   212511
# 5255    67          7     99     0.39   250   212511
#
#                          description        name    median  price_y         p  \
# 99    FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.807917     10.0  0.655833
# 100   FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.807917   1020.0  0.049583
# 101   FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.807917   2030.0  0.029167
# 102   FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.807917   3040.0  0.045417
# 103   FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.807917   4050.0  0.027917
# ...                              ...         ...       ...      ...       ...
# 5251  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.467500   4050.0  0.021250
# 5252  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.467500   5060.0  0.014167
# 5253  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.467500   6070.0  0.007500
# 5254  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.467500   7080.0  0.028750
# 5255  FRESH VEG-LETTUCE-ICEBERG-EACH  C. Lettuce  0.467500   8090.0  0.045833
#
#       keep    newDate       _merge  Year  Month
# 99     1.0 1988-03-01  matched (3)  1988      3
# 100    1.0 1988-03-01  matched (3)  1988      3
# 101    1.0 1988-03-01  matched (3)  1988      3
# 102    1.0 1988-03-01  matched (3)  1988      3
# 103    1.0 1988-03-01  matched (3)  1988      3
# ...    ...        ...          ...   ...    ...
# 5251   1.0 1993-08-01  matched (3)  1993      8
# 5252   1.0 1993-08-01  matched (3)  1993      8
# 5253   1.0 1993-08-01  matched (3)  1993      8
# 5254   1.0 1993-08-01  matched (3)  1993      8
# 5255   1.0 1993-08-01  matched (3)  1993      8
#
# [459 rows x 16 columns]

# %%
lettuce_data.duplicated().value_counts()
# Out:
# False    39726
# dtype: int64
